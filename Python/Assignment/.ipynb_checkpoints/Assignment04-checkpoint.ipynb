# %% [markdown]
# ## 주어진 시계열 데이터에서 이상치 탐지 및 처리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
# 데이터 생성
dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
values = np.random.randn(100) * 10

# 이상치 추가
for i in range(10,100, 10) : 
    values[i] = 100

# 데이터 프레임 생성
data = pd.DataFrame({
    'Date' : dates,
    'Value' : values
})

# %%
# 이상치 탐지
z_scores = np.abs(stats.zscore(data['Value']))

# 임계치 설정
threshold = 3

# z-scores 임계값 초과하는 체크
outliers = z_scores > threshold

# 이상치를 -> 결측치로 처리 
data.loc[outliers, 'Value'] = np.nan

# 결측치 보간 
data['Value'] = data['Value'].interpolate()

# %%
# 시계열 데이터 시각화
plt.plot(data['Date'], data['Value'], label='Original')
plt.scatter(data[outliers]['Date'], data[outliers]['Value'], color='red', label='Outliers')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Outlier Detection and Handling in Time Series Data')
plt.xticks(rotation=-45)
plt.legend()
plt.show()

# 처리된 데이터 확인
for i in data.loc[outliers, 'Value']: 
    print("이상치 처리된 데이터 확인 >> " , i)
# Out:
# 이상치 처리된 데이터 확인 >>  0.27065875260277283
# 이상치 처리된 데이터 확인 >>  -6.166970785686372
# 이상치 처리된 데이터 확인 >>  5.279648226739832
# 이상치 처리된 데이터 확인 >>  15.677210954654228
# 이상치 처리된 데이터 확인 >>  -2.5371931118430497
# 이상치 처리된 데이터 확인 >>  -3.5611217490707303
# 이상치 처리된 데이터 확인 >>  3.152635628020805
# 이상치 처리된 데이터 확인 >>  12.66156205933827
# 이상치 처리된 데이터 확인 >>  12.168098552230283
