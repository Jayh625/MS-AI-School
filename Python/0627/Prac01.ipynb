# %% [markdown]
# ### 공개되어 있는 데이터를 가지고 로지스틱 회귀 진행 실습
#
# - 각 이미지 크기는 28 x 28 / 흑백 이미지 / 총 10개의 클래스

# %%
"""
Fashion-MNIST 라벨 구성 요소
0 - 티셔츠 
1 - 바지
2 - 스웨터 
3 - 드레스 
4 - 코트 
5 - 샌들 
6 - 셔츠 
7 - 운동화 
8 - 가방
9 - 앵글 부츠 
"""

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dataset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %% [markdown]
# #### 데이터셋 다운로드 하고 Dataloader 생성하기

# %%
# 데이터셋 다운로드 및 Dataloader 생성 
train_dataset = dataset.FashionMNIST(root="./data", train=True, transform=transforms.ToTensor(),download=False)
test_dataset = dataset.FashionMNIST(root="./data", train=False, transform=transforms.ToTensor(),download=False)

# train Loader test Loader 설정 
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size = 100, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size = 100, shuffle=False)

# %% [markdown]
# #### 모델 정의

# %%
class LogisticRegression(nn.Module) : 
    def __init__(self, input_size, num_classes) : 
        super(LogisticRegression, self).__init__() 
        self.linear = nn.Linear(input_size, num_classes)
    
    def forward(self, x) : 
        out = self.linear(x)
        return out

# %% [markdown]
# #### 하이퍼 파라미터 설정

# %%
input_size = 28 * 28
num_classes = 10
num_epochs = 10
lr = 0.001

total_step = len(train_loader)

# %% [markdown]
# #### 모델, Loss, 옵티마이저 정의

# %%
model = LogisticRegression(input_size=input_size, num_classes=num_classes)
# print(model)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)

# device setting 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using Device >>" , device)

model.to(device)
# Out:
# Using Device >> cpu
# LogisticRegression(
#   (linear): Linear(in_features=784, out_features=10, bias=True)
# )

# %% [markdown]
# #### train loop

# %%
loss_list = []
acc_list = []

for epoch in range(num_epochs) :
    correct = 0
    total = 0 
    for i, (images, labels) in enumerate(train_loader) : 
        # 데이터 로드 
        images = images.reshape(-1, input_size).to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        
        # 순전파 및 Loss 계산 
        ouptuts = model(images)
        loss = criterion(ouptuts, labels)
        
        # 역전파 및 가중치 업데이트 
        loss.backward()
        optimizer.step()
        
        # 로그 출력 
        if (i+1) % 100 == 0 :
            loss_list.append(loss.item())
            _, predicted = torch.max(ouptuts.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            acc_list.append(correct / total)
            
            print("Epoch [{}/{}], Step [{}/{}], Loss : {:.4f}, Train ACC : {:.4f}".format(
                epoch+1, num_epochs, i+1, total_step, loss.item(), acc_list[-1]))
            
            
# 손실 및 정확도 그래프 출력 
plt.plot(loss_list, label="Train loss")
plt.plot(acc_list, label="Train acc")
plt.xlabel('Iterations')
plt.ylabel('Loss / ACC')
plt.legend()
plt.show()
# Out:
# Epoch [1/10], Step [100/600], Loss : 1.4283, Train ACC : 0.6000
# Epoch [1/10], Step [200/600], Loss : 1.0655, Train ACC : 0.6500
# Epoch [1/10], Step [300/600], Loss : 1.0491, Train ACC : 0.6533
# Epoch [1/10], Step [400/600], Loss : 0.7936, Train ACC : 0.6825
# Epoch [1/10], Step [500/600], Loss : 0.9292, Train ACC : 0.6800
# Epoch [1/10], Step [600/600], Loss : 0.7063, Train ACC : 0.6900
# Epoch [2/10], Step [100/600], Loss : 0.7559, Train ACC : 0.8100
# Epoch [2/10], Step [200/600], Loss : 0.8256, Train ACC : 0.7600
# Epoch [2/10], Step [300/600], Loss : 0.7375, Train ACC : 0.7600
# Epoch [2/10], Step [400/600], Loss : 0.7335, Train ACC : 0.7575
# Epoch [2/10], Step [500/600], Loss : 0.6540, Train ACC : 0.7620
# Epoch [2/10], Step [600/600], Loss : 0.6715, Train ACC : 0.7617
# Epoch [3/10], Step [100/600], Loss : 0.7241, Train ACC : 0.8000
# Epoch [3/10], Step [200/600], Loss : 0.7222, Train ACC : 0.7950
# Epoch [3/10], Step [300/600], Loss : 0.5429, Train ACC : 0.8233
# Epoch [3/10], Step [400/600], Loss : 0.5949, Train ACC : 0.8200
# Epoch [3/10], Step [500/600], Loss : 0.5564, Train ACC : 0.8180
# Epoch [3/10], Step [600/600], Loss : 0.6301, Train ACC : 0.8050
# Epoch [4/10], Step [100/600], Loss : 0.5234, Train ACC : 0.8100
# Epoch [4/10], Step [200/600], Loss : 0.6195, Train ACC : 0.7850
# Epoch [4/10], Step [300/600], Loss : 0.5503, Train ACC : 0.8067
# Epoch [4/10], Step [400/600], Loss : 0.6911, Train ACC : 0.7950
# Epoch [4/10], Step [500/600], Loss : 0.6134, Train ACC : 0.7960
# Epoch [4/10], Step [600/600], Loss : 0.5688, Train ACC : 0.7933
# Epoch [5/10], Step [100/600], Loss : 0.6225, Train ACC : 0.8000
# Epoch [5/10], Step [200/600], Loss : 0.5800, Train ACC : 0.7900
# Epoch [5/10], Step [300/600], Loss : 0.6787, Train ACC : 0.7900
# Epoch [5/10], Step [400/600], Loss : 0.5137, Train ACC : 0.8025
# Epoch [5/10], Step [500/600], Loss : 0.5449, Train ACC : 0.8140
# Epoch [5/10], Step [600/600], Loss : 0.5703, Train ACC : 0.8150
# Epoch [6/10], Step [100/600], Loss : 0.6499, Train ACC : 0.7900
# Epoch [6/10], Step [200/600], Loss : 0.4373, Train ACC : 0.8350
# Epoch [6/10], Step [300/600], Loss : 0.5132, Train ACC : 0.8467
# Epoch [6/10], Step [400/600], Loss : 0.5671, Train ACC : 0.8350
# Epoch [6/10], Step [500/600], Loss : 0.6086, Train ACC : 0.8220
# Epoch [6/10], Step [600/600], Loss : 0.5709, Train ACC : 0.8167
# Epoch [7/10], Step [100/600], Loss : 0.4973, Train ACC : 0.8100
# Epoch [7/10], Step [200/600], Loss : 0.5453, Train ACC : 0.8250
# Epoch [7/10], Step [300/600], Loss : 0.6182, Train ACC : 0.8167
# Epoch [7/10], Step [400/600], Loss : 0.5332, Train ACC : 0.8050
# Epoch [7/10], Step [500/600], Loss : 0.5788, Train ACC : 0.8080
# Epoch [7/10], Step [600/600], Loss : 0.6174, Train ACC : 0.8100
# Epoch [8/10], Step [100/600], Loss : 0.6964, Train ACC : 0.7800
# Epoch [8/10], Step [200/600], Loss : 0.5968, Train ACC : 0.8150
# Epoch [8/10], Step [300/600], Loss : 0.5963, Train ACC : 0.8033
# Epoch [8/10], Step [400/600], Loss : 0.4815, Train ACC : 0.8200
# Epoch [8/10], Step [500/600], Loss : 0.5162, Train ACC : 0.8240
# Epoch [8/10], Step [600/600], Loss : 0.5284, Train ACC : 0.8283
# Epoch [9/10], Step [100/600], Loss : 0.5652, Train ACC : 0.8200
# Epoch [9/10], Step [200/600], Loss : 0.5821, Train ACC : 0.8150
# Epoch [9/10], Step [300/600], Loss : 0.4879, Train ACC : 0.8167
# Epoch [9/10], Step [400/600], Loss : 0.6541, Train ACC : 0.8075
# Epoch [9/10], Step [500/600], Loss : 0.5242, Train ACC : 0.8160
# Epoch [9/10], Step [600/600], Loss : 0.5289, Train ACC : 0.8133
# Epoch [10/10], Step [100/600], Loss : 0.3821, Train ACC : 0.8900
# Epoch [10/10], Step [200/600], Loss : 0.5790, Train ACC : 0.8550
# Epoch [10/10], Step [300/600], Loss : 0.4705, Train ACC : 0.8433
# Epoch [10/10], Step [400/600], Loss : 0.4456, Train ACC : 0.8425
# Epoch [10/10], Step [500/600], Loss : 0.5255, Train ACC : 0.8400
# Epoch [10/10], Step [600/600], Loss : 0.6039, Train ACC : 0.8333

# %% [markdown]
# #### 테스트 시각화

# %%
import numpy as np

# 테스트 이미지 가져오기
dataiter = iter(test_loader)
images, labels = dataiter.__next__()
images = images.reshape(-1, 28 * 28)

# 모델 예측
model.eval()
outputs_temp = model(images)
_, predicted_test = torch.max(outputs_temp.data, 1)

# 이미지와 예측값 시각화
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(8,8), subplot_kw={'xticks' : [], 'yticks' : []})
for i, ax in enumerate(axes.flat) :
    ax.imshow(np.squeeze(images[i].reshape(28,28)), cmap='gray')
    ax.set_title(f"Predicted : {predicted_test[i].item()}")

plt.tight_layout()
plt.show()
