# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
math_scores = np.random.normal(loc=70, scale=10, size=(300,))
english_scores = np.random.normal(loc=80, scale=10, size=(300,))
korean_scores = np.random.normal(loc=75, scale=10, size=(300,))

# %%
grades = np.repeat([1,2,3], 100)

# %%
df = pd.DataFrame({
    'Grade' : grades,
    'Math' : math_scores,
    'English' : english_scores,
    'Korean' : korean_scores
})
df.to_csv('./data/student_score.csv', index=False)

# %%
df = pd.read_csv('./data/student_score.csv')
df
# Out:
#      Grade       Math    English     Korean
# 0        1  74.967142  71.710050  82.569886
# 1        1  68.617357  74.398190  65.778347
# 2        1  76.476885  87.472936  83.696059
# 3        1  85.230299  86.103703  88.556379
# 4        1  67.658466  79.790984  79.134349
# ..     ...        ...        ...        ...
# 295      3  63.070904  74.899836  81.487099
# 296      3  78.995999  77.301251  73.328819
# 297      3  73.072995  70.212363  76.467137
# 298      3  78.128621  75.557067  87.065090
# 299      3  76.296288  83.773005  66.830643
#
# [300 rows x 4 columns]

# %%
plt.hist(df['Math'], bins=10)
plt.show()

# %%
corr = df.corr()
sns.heatmap(corr, annot=True)
plt.show()
